# %% [markdown]
# # Figure 2
#
# This notebook runs the primary realized-price Figure 2 workflow used in the current release. It then previews the composite figure and selected Source Data tables for the Pareto frontier, endpoint bars, and crop-transition outputs.

# %%
from pathlib import Path
import subprocess
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
print(f'Repository root: {ROOT}')

# %%
subprocess.run([str(ROOT / 'run_figure2.sh')], check=True)
print('Figure 2 regenerated.')

# %%
display(Image(filename=str(ROOT / 'figures' / 'working_variants' / 'figure2_main.png')))

# %%
pd.read_csv(ROOT / 'submission_assets' / 'source_data' / 'csv' / 'Fig2a_pareto.csv').head()

# %%
pd.read_csv(ROOT / 'submission_assets' / 'source_data' / 'csv' / 'Fig2b_values.csv')

# %%
pd.read_csv(ROOT / 'submission_assets' / 'source_data' / 'csv' / 'Fig2d_flows.csv').head()
