# %% [markdown]
# # Supplementary Figures and Source Data
#
# This notebook runs the supplementary robustness block shipped with the cleaned package. It then previews two key supplementary figures and lists the current Source Data CSV exports.

# %%
from pathlib import Path
import subprocess
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
print(f'Repository root: {ROOT}')

# %%
subprocess.run([str(ROOT / 'run_supplementary.sh')], check=True)
print('Supplementary block regenerated.')

# %%
display(Image(filename=str(ROOT / 'figures' / 'manuscript_final' / 'si_revenue_benchmark_robustness.png')))

# %%
display(Image(filename=str(ROOT / 'figures' / 'manuscript_final' / 'si_figure2a_frontier_bootstrap.png')))

# %%
source_csv_dir = ROOT / 'submission_assets' / 'source_data' / 'csv'
pd.DataFrame({'source_data_csv': sorted(p.name for p in source_csv_dir.glob('*.csv'))})

# %%
pd.read_csv(ROOT / 'submission_assets' / 'source_data' / 'csv' / 'TableS10_prices.csv').head()
