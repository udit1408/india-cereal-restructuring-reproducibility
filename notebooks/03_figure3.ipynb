# %% [markdown]
# # Figure 3
#
# Figure 3 depends on the nitrogen-focused optimized area table from Figure 2. This notebook checks that dependency, reruns Figure 3, and previews the state-area and trade-network source tables.

# %%
from pathlib import Path
import subprocess
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
print(f'Repository root: {ROOT}')

# %%
required = ROOT / 'data' / 'generated' / 'figure2_main' / 'figure2_main_panel_d_optimized_areas.csv'
if not required.exists():
    subprocess.run([str(ROOT / 'run_figure2.sh')], check=True)
subprocess.run([str(ROOT / 'run_figure3.sh')], check=True)
print('Figure 3 regenerated.')

# %%
display(Image(filename=str(ROOT / 'figures' / 'working_variants' / 'figure3_main.png')))

# %%
pd.read_csv(ROOT / 'submission_assets' / 'source_data' / 'csv' / 'Fig3a_state_area.csv').head()

# %%
pd.read_csv(ROOT / 'submission_assets' / 'source_data' / 'csv' / 'Fig3b_edges.csv').head()

# %%
pd.read_csv(ROOT / 'submission_assets' / 'source_data' / 'csv' / 'Fig3c_edges.csv').head()
